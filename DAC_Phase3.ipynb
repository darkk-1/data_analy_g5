# %% [markdown]
# # **Step 1: Import Necessary Libraries**
#
# Make sure you have Python and the Pandas library installed. You can install Pandas using pip if it's not already installed:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Step 2: Load the Dataset**
# Assuming you have downloaded the dataset as a CSV file, you can load it into a Pandas DataFrame like this:

# %%
# Load the dataset
d = pd.read_csv('/content/water_potability.csv')

# %% [markdown]
# # **Step 3: Preprocess the Data**
# Data preprocessing may involve various tasks, such as handling missing values, data cleaning, and feature engineering. Here are some common preprocessing steps:
#
# ##**Handle Missing Values:**
# If there are missing values in the dataset, you can use Pandas to fill them or drop rows/columns with missing values.

# %%
d.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
d.fillna(d.mean(),inplace=True)

# %% [markdown]
# ### **outlier detection and handling**
#
# Detection of outliers isn’t a trivial problem. We’re trying to identify observations that don’t fit into the general characteristics of the dataset.
#
# Detection and handling of outliers is a fundamental problem in data science and machine learning. Solving this problem isn’t straightforward, just like the missing values problem.

# %% [markdown]
# **Outlier:Solids**

# %%
l=d.Solids
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 142     0.752290
# 186     0.737224
# 283     0.793032
# 287     0.751861
# 366     0.853738
# 378     0.737667
# 405     0.765290
# 516     0.741954
# 546     0.800473
# 613     0.731411
# 666     0.849491
# 987     0.782861
# 1031    0.928425
# 1068    0.903253
# 1077    0.789566
# 1096    0.735897
# 1186    0.919946
# 1302    0.731880
# 1332    0.736311
# 1343    0.786179
# 1445    0.736307
# 1462    0.748999
# 1527    0.761787
# 1554    0.922200
# 1556    0.737561
# 1746    0.801304
# 1784    0.820249
# 1815    0.734247
# 1858    0.751260
# 1955    0.799409
# 1984    0.766782
# 2012    0.780412
# 2497    0.804851
# 2602    1.000000
# 2680    0.785714
# 2758    0.776116
# 2891    0.734392
# 2993    0.736014
# 3014    0.806742
# 3062    0.733287
# 3130    0.828699
# 3150    0.919440
# 3162    0.877003
# 3190    0.818399
# 3226    0.844099
# 3236    0.782956
# 3271    0.775947
# Name: Solids, dtype: float64

# %%
d.Solids[d.Solids>up]=low
# Out:
# <ipython-input-89-9d003c82da2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Solids[d.Solids>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# Series([], Name: Solids, dtype: float64)

# %% [markdown]
# **Outlier:ph**

# %%
l=d.ph
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 1        3.716080
# 26       3.445062
# 36       3.641630
# 76       3.514546
# 77       3.722500
# 80       1.844538
# 88      10.155440
# 104      2.612036
# 113      3.388091
# 194      3.719792
# 234      3.664711
# 326      3.657123
# 347      3.551579
# 354      2.798549
# 546      3.410360
# 681      3.623166
# 692      1.757037
# 712      3.681076
# 721      3.633163
# 726      0.227499
# 756      3.426450
# 810      0.989912
# 1068     3.344589
# 1182     3.637171
# 1231     2.690831
# 1301     3.433874
# 1343     2.569244
# 1414     3.590822
# 1448     3.434856
# 2097    10.164839
# 2099     3.717704
# 2112     3.715171
# 2141     3.691933
# 2165     2.803563
# 2189     2.558103
# 2300     2.974429
# 2343     2.538116
# 2473     2.945469
# 2492    10.164173
# 2546     3.148712
# 2631     3.230973
# 2655     3.422394
# 2681     2.376768
# 2694     3.676845
# 2699     3.272820
# 2899     1.431782
# 2907     3.261670
# 2928     0.975578
# 2932     2.925174
# 2987     3.730128
# 2989     3.678432
# 2993     3.102076
# 3014     0.000000
# 3088     2.128531
# 3094     1.985383
# 3107     3.337629
# 3261     3.629922
# Name: ph, dtype: float64

# %%
d.ph[d.ph>up]=low
# Out:
# <ipython-input-104-58c25e1715eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.ph[d.ph>up]=low

# %%
l[(l<low) | (l>up)].count()
# Out:
# 54

# %% [markdown]
# **Outlier:Hardness**

# %%
l=d.Hardness
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 18      279.357167
# 37      304.235912
# 51      100.457615
# 67      103.464759
# 71      116.299330
#            ...
# 3218    287.975540
# 3221    303.702627
# 3230    114.807578
# 3244    277.065713
# 3269     94.812545
# Name: Hardness, Length: 83, dtype: float64

# %%
d.Hardness[d.Hardness>up]=low
# Out:
# <ipython-input-108-2cae41d286ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Hardness[d.Hardness>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 51      100.457615
# 67      103.464759
# 71      116.299330
# 149     104.752425
# 189     112.299485
# 215     105.859264
# 227     112.820254
# 246     103.173587
# 258      98.771644
# 263      47.432000
# 278      81.710895
# 309     113.831112
# 317      77.459586
# 335      94.091307
# 379      73.492234
# 1525    108.699077
# 1536    106.380113
# 1542     97.280909
# 1649     98.452931
# 1650    116.061950
# 1743    107.383327
# 1815    116.725122
# 1829    113.504698
# 1858    115.392979
# 1859    117.057314
# 1868    110.865788
# 2044    108.916629
# 2343    100.806520
# 2383    107.341982
# 2400    111.246412
# 2418    116.905479
# 2606    116.338278
# 2648    113.024472
# 2715    111.478582
# 2742    113.175965
# 2775    114.463900
# 2777    111.994028
# 2811    114.733545
# 2877    114.371450
# 3179     94.908977
# 3186    110.903598
# 3217     98.367915
# 3230    114.807578
# 3269     94.812545
# Name: Hardness, dtype: float64

# %% [markdown]
# **Outlier:Chloramines**

# %%
l=d.Chloramines
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 272     12.580026
# 275     13.043806
# 285      0.530351
# 287     12.912187
# 304     12.363285
#           ...
# 2677     2.562255
# 2694    12.653362
# 2699    11.996015
# 2714     2.648390
# 2796     3.016033
# Name: Chloramines, Length: 61, dtype: float64

# %%
d.Chloramines[d.Chloramines>up]=low
# Out:
# <ipython-input-112-5c7899d64226>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Chloramines[d.Chloramines>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 285     0.530351
# 408     2.484380
# 437     2.981379
# 454     2.993744
# 509     1.683993
# 651     2.750837
# 666     2.577555
# 772     2.866073
# 806     2.862535
# 1106    2.741712
# 1698    2.456014
# 1776    3.139553
# 1868    2.621268
# 2206    2.458609
# 2212    2.785718
# 2300    2.498597
# 2302    0.352000
# 2326    3.117441
# 2346    2.855790
# 2350    1.390871
# 2352    2.397985
# 2401    1.920271
# 2449    2.386653
# 2470    2.102691
# 2511    3.124833
# 2535    2.726766
# 2566    2.654491
# 2586    3.074316
# 2677    2.562255
# 2714    2.648390
# 2796    3.016033
# Name: Chloramines, dtype: float64

# %% [markdown]
# **Outlier:Sulfate**

# %%
l=d.Sulfate
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 9       404.041635
# 51      247.200826
# 84      266.908428
# 112     426.543590
# 118     241.607532
#            ...
# 3115    407.417977
# 3116    413.914001
# 3162    254.040977
# 3176    264.052839
# 3269    258.930600
# Name: Sulfate, Length: 264, dtype: float64

# %%
d.Sulfate[d.Sulfate>up]=low
# Out:
# <ipython-input-116-7497be8b425b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Sulfate[d.Sulfate>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 51      247.200826
# 84      266.908428
# 118     241.607532
# 130     240.936722
# 199     261.444798
#            ...
# 3023    238.844004
# 3082    267.026093
# 3162    254.040977
# 3176    264.052839
# 3269    258.930600
# Name: Sulfate, Length: 129, dtype: float64

# %% [markdown]
# **Outlier:Conductivity**

# %%
l=d.Conductivity
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 66      0.853779
# 140     0.858732
# 342     0.898623
# 1183    0.831395
# 1269    0.837219
# 1295    0.848473
# 1384    0.000000
# 2134    0.921106
# 2704    1.000000
# 2737    0.832525
# 3142    0.862030
# Name: Conductivity, dtype: float64

# %%
d.Conductivity[d.Conductivity>up]=low
# Out:
# <ipython-input-120-99cb504c1183>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Conductivity[d.Conductivity>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 1384    0.0
# Name: Conductivity, dtype: float64

# %% [markdown]
# **Outlier:Organic_carbon**

# %%
l=d.Organic_carbon
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 43      23.917601
# 227     23.399516
# 333      5.315287
# 420     23.373265
# 558     23.514774
# 698     23.569645
# 785      2.200000
# 876      4.966862
# 1055    23.952450
# 1390     4.371899
# 1447     4.861631
# 1536     5.218233
# 1663     4.473092
# 1689     5.051695
# 1792    28.300000
# 1827    23.317699
# 2057    24.755392
# 2082     5.188466
# 2138     4.902888
# 2224     4.466772
# 2236    27.006707
# 2414     5.196717
# 2601    23.667667
# 2680     5.159380
# 3169    23.604298
# Name: Organic_carbon, dtype: float64

# %%
d.Organic_carbon[d.Organic_carbon>up]=low
# Out:
# <ipython-input-124-d61115c30e93>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Organic_carbon[d.Organic_carbon>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 333     5.315287
# 785     2.200000
# 876     4.966862
# 1390    4.371899
# 1447    4.861631
# 1536    5.218233
# 1663    4.473092
# 1689    5.051695
# 2082    5.188466
# 2138    4.902888
# 2224    4.466772
# 2414    5.196717
# 2680    5.159380
# Name: Organic_carbon, dtype: float64

# %% [markdown]
# **Outlier:Trihalomethanes**

# %%
l=d.Trihalomethanes
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]

# %%
d.Trihalomethanes[d.Trihalomethanes>up]=low

# %%
l[(l<low) | (l>up)]

# %% [markdown]
# **Outlier: Turbidity**

# %%
l=d.Turbidity
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]

# %%
d.Turbidity[d.Turbidity>up]=low

# %%
l[(l<low) | (l>up)]

# %% [markdown]
# # **Step 4: Create Visualizations**
# Use data visualization libraries such as Matplotlib and Seaborn to create visualizations that help convey your findings.
# ### **Explore correlations between different parameters**
# **Correlation:**Correlation refers to the statistical relationship between the two entities.
#
# **Heat map:**A heat map represents these coefficients to visualize the strength of correlation among variables.

# %%
# Explore correlations between different parameters
correlation_matrix = d.corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### **visualizing distribution of data for all column using histogram & countplot**
# Data visualization is the representation of data through use of common graphics, such as charts, plots, infographics, and even animations.
#
# **Parameter Distribution:**The parameters of a distribution are variables included in the density function so that the distribution can be adapted to a variety of situations.
#
# **Histogram:**A histogram is a graph that shows the frequency of numerical data using rectangles.
#
# **countplot:**A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(15, 20))
#plot 1:
plt.subplot(4, 2, 1)
plt.hist(d.ph , bins=14,align='mid', edgecolor='w')
#plot 2:
plt.subplot(4, 2, 2)
plt.hist(d.Hardness , bins=10,align='mid', edgecolor='w')
#plot 3:
plt.subplot(4, 2, 3)
plt.hist(d.Solids , bins=10,align='mid', edgecolor='w')
#plot 4:
plt.subplot(4, 2, 4)
plt.hist(d.Chloramines , bins=10,align='mid', edgecolor='w')
plot 5:
plt.subplot(4, 2, 5)
plt.hist(d.Sulfate , bins=10,align='mid', edgecolor='w')
#plot 6:
plt.subplot(4, 2, 6)
plt.hist(d.Conductivity , bins=10,align='mid', edgecolor='w')
#plot 7:
plt.subplot(4, 2, 7)
plt.hist(d.Organic_carbon , bins=10,align='mid', edgecolor='w')
#plot 8:
plt.subplot(4, 2, 8)
plt.hist(d.Trihalomethanes , bins=10,align='mid', edgecolor='w')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.hist(d.Turbidity , bins=10,align='mid', edgecolor='w')
plt.subplot(1,2,2)
sns.countplot(x='Potability',data=d )
# Out:
# <Axes: xlabel='Potability', ylabel='count'>

# %% [markdown]
# ### **visualizing standard deviation from mean for all column using boxplot**
# **standard deviation:**The standard deviation is the average amount of variability in your dataset. It tells you, on average, how far each value lies from the mean. A high standard deviation means that values are generally far from the mean, while a low standard deviation indicates that values are clustered close to the mean
#
# **Boxplot:**A box and whisker plot—also called a box plot—displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum.

# %%
d.fillna(d.mean(),inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(15, 20))
#plot 1:
plt.subplot(4, 2, 1)
plt.boxplot(d.ph )
#plot 2:
plt.subplot(4, 2, 2)
plt.boxplot(d.Hardness)
#plot 3:
plt.subplot(4, 2, 3)
plt.boxplot(d.Solids )
#plot 4:
plt.subplot(4, 2, 4)
plt.boxplot(d.Chloramines)
#plot 5:
plt.subplot(4, 2, 5)
plt.boxplot(d.Sulfate )
#plot 6:
plt.subplot(4, 2, 6)
plt.boxplot(d.Conductivity)
#plot 7:
plt.subplot(4, 2, 7)
plt.boxplot(d.Organic_carbon )
#plot 8:
plt.subplot(4, 2, 8)
plt.boxplot(d.Trihalomethanes)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.boxplot(d.Turbidity)
#plot 8:
plt.subplot(1, 2, 2)
plt.boxplot(d.Potability)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b3016ace1a0>,
#   <matplotlib.lines.Line2D at 0x7b3016acc220>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b3016acfdf0>,
#   <matplotlib.lines.Line2D at 0x7b3016aceb30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b3016acfdc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b3016acd600>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b3016acf4c0>],
#  'means': []}
