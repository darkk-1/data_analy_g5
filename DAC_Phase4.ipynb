# %% [markdown]
# # **Step 1: Import Necessary Libraries**
# Make sure you have Python and the Pandas library installed. You can install Pandas using pip if it's not already installed:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %% [markdown]
# # **Step 2:Loading data**
# Assuming you have downloaded the dataset as a CSV file, you can load it into a Pandas DataFrame like this:

# %%
d=pd.read_csv("/content/water_potability.csv")

# %% [markdown]
# # **Step 3: Data manipulation using pandas**
# **Data Manipulation:**Data Manipulation is one of the initial processes done in Data Analysis. It involves arranging or rearranging data points to make it easier for users/data analysts to perform necessary insights or business directives.
#
# **Pandas:**Pandas is a Python library used for working with data sets.
# It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
d.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
d.shape
# Out:
# (3276, 10)

# %%
d.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
d.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
d.fillna(d.mean(),inplace=True)

# %%
d.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# # **Step 4:Visualization**
# Use data visualization libraries such as Matplotlib and Seaborn to create visualizations that help convey your findings.

# %%
sns.distplot(d['ph'])
# Out:
# <ipython-input-10-b0f2a193d66c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['ph'])
# <Axes: xlabel='ph', ylabel='Density'>

# %%
sns.distplot(d['Hardness'])
# Out:
# <ipython-input-11-115dcf99d50b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Hardness'])
# <Axes: xlabel='Hardness', ylabel='Density'>

# %%
sns.distplot(d['Solids'])
# Out:
# <ipython-input-12-98b84c92cd98>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Solids'])
# <Axes: xlabel='Solids', ylabel='Density'>

# %%
sns.distplot(d['Chloramines'])
# Out:
# <ipython-input-13-f2c9a2b8840a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Chloramines'])
# <Axes: xlabel='Chloramines', ylabel='Density'>

# %%
sns.distplot(d['Sulfate'])
# Out:
# <ipython-input-14-d870a2577e28>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Sulfate'])
# <Axes: xlabel='Sulfate', ylabel='Density'>

# %%
sns.distplot(d['Conductivity'])
# Out:
# <ipython-input-15-f28589557604>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Conductivity'])
# <Axes: xlabel='Conductivity', ylabel='Density'>

# %%
sns.distplot(d['Organic_carbon'])
# Out:
# <ipython-input-16-4a751f105dd5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Organic_carbon'])
# <Axes: xlabel='Organic_carbon', ylabel='Density'>

# %%
sns.distplot(d['Trihalomethanes'])
# Out:
# <ipython-input-17-cce319a3753d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Trihalomethanes'])
# <Axes: xlabel='Trihalomethanes', ylabel='Density'>

# %%
sns.distplot(d['Turbidity'])
# Out:
# <ipython-input-18-95b23c5c6ee8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['Turbidity'])
# <Axes: xlabel='Turbidity', ylabel='Density'>

# %%
sns.countplot(x='Potability',data=d)
# Out:
# <Axes: xlabel='Potability', ylabel='count'>

# %%
correlation_matrix = d.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='PiYG',fmt='.2f')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(15, 20))
#plot 1:
plt.subplot(4, 2, 1)
plt.hist(d.ph , bins=14,align='mid', edgecolor='w')
#plot 2:
plt.subplot(4, 2, 2)
plt.hist(d.Hardness , bins=10,align='mid', edgecolor='w')
#plot 3:
plt.subplot(4, 2, 3)
plt.hist(d.Solids , bins=10,align='mid', edgecolor='w')
#plot 4:
plt.subplot(4, 2, 4)
plt.hist(d.Chloramines , bins=10,align='mid', edgecolor='w')
#plot 5:
plt.subplot(4, 2, 5)
plt.hist(d.Sulfate , bins=10,align='mid', edgecolor='w')
#plot 6:
plt.subplot(4, 2, 6)
plt.hist(d.Conductivity , bins=10,align='mid', edgecolor='w')
#plot 7:
plt.subplot(4, 2, 7)
plt.hist(d.Organic_carbon , bins=10,align='mid', edgecolor='w')
#plot 8:
plt.subplot(4, 2, 8)
plt.hist(d.Trihalomethanes , bins=10,align='mid', edgecolor='w')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(15, 20))
#plot 1:
plt.subplot(4, 2, 1)
plt.boxplot(d.ph )
#plot 2:
plt.subplot(4, 2, 2)
plt.boxplot(d.Hardness)
#plot 3:
plt.subplot(4, 2, 3)
plt.boxplot(d.Solids )
#plot 4:
plt.subplot(4, 2, 4)
plt.boxplot(d.Chloramines)
#plot 5:
plt.subplot(4, 2, 5)
plt.boxplot(d.Sulfate )
#plot 6:
plt.subplot(4, 2, 6)
plt.boxplot(d.Conductivity)
#plot 7:
plt.subplot(4, 2, 7)
plt.boxplot(d.Organic_carbon )
#plot 8:
plt.subplot(4, 2, 8)
plt.boxplot(d.Trihalomethanes)
plt.show()

# %%
# Create scatter plots
sns.pairplot(d, hue='Potability')
plt.show()

# %%
sns.scatterplot(data=d,x="Solids",y="ph",hue="Hardness")

# %%
sns.scatterplot(data=d,x="Sulfate",y="Conductivity",c="red")

# %%
sns.scatterplot(data=d,x="Chloramines",y="Conductivity",c="green")

# %% [markdown]
# # **Step 5: Preprocessing**
# Data preprocessing may involve various tasks, such as handling missing values, data cleaning, and feature engineering.

# %% [markdown]
# #### **detect missing and null values and filling**

# %%
d.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
d.fillna(d.mean(),inplace=True)

# %%
d.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# #### **outlier detection and handling**
#
# Detection of outliers isn’t a trivial problem. We’re trying to identify observations that don’t fit into the general characteristics of the dataset.
#
# Detection and handling of outliers is a fundamental problem in data science and machine learning. Solving this problem isn’t straightforward, just like the missing values problem.
#
#
#
#
# **Outlier:Solids**

# %%
l=d.Solids
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 946    44376.187382
# Name: Solids, dtype: float64

# %%
d.Solids[d.Solids>up]=low
# Out:
# <ipython-input-123-9d003c82da2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Solids[d.Solids>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# Series([], Name: Solids, dtype: float64)

# %% [markdown]
# **Outlier:ph**

# %%
l=d.ph
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 1        3.716080
# 26       3.445062
# 36       3.641630
# 76       3.514546
# 77       3.722500
# 80       1.844538
# 88      10.155440
# 104      2.612036
# 113      3.388091
# 194      3.719792
# 234      3.664711
# 326      3.657123
# 347      3.551579
# 354      2.798549
# 546      3.410360
# 681      3.623166
# 692      1.757037
# 712      3.681076
# 721      3.633163
# 726      0.227499
# 756      3.426450
# 810      0.989912
# 1068     3.344589
# 1182     3.637171
# 1231     2.690831
# 1301     3.433874
# 1343     2.569244
# 1414     3.590822
# 1448     3.434856
# 2097    10.164839
# 2099     3.717704
# 2112     3.715171
# 2141     3.691933
# 2165     2.803563
# 2189     2.558103
# 2300     2.974429
# 2343     2.538116
# 2473     2.945469
# 2492    10.164173
# 2546     3.148712
# 2631     3.230973
# 2655     3.422394
# 2681     2.376768
# 2694     3.676845
# 2699     3.272820
# 2899     1.431782
# 2907     3.261670
# 2928     0.975578
# 2932     2.925174
# 2987     3.730128
# 2989     3.678432
# 2993     3.102076
# 3014     0.000000
# 3088     2.128531
# 3094     1.985383
# 3107     3.337629
# 3261     3.629922
# Name: ph, dtype: float64

# %%
d.ph[d.ph>up]=low
# Out:
# <ipython-input-127-58c25e1715eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.ph[d.ph>up]=low

# %%
l[(l<low) | (l>up)].count()
# Out:
# 54

# %% [markdown]
# **Outlier:Hardness**

# %%
l=d.Hardness
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 51      100.457615
# 67      103.464759
# 149     104.752425
# 189     112.299485
# 215     105.859264
# 227     112.820254
# 246     103.173587
# 258      98.771644
# 263      47.432000
# 278      81.710895
# 309     113.831112
# 317      77.459586
# 326     275.767142
# 335      94.091307
# 379      73.492234
# 1525    108.699077
# 1536    106.380113
# 1542     97.280909
# 1649     98.452931
# 1743    107.383327
# 1747    115.300182
# 1790    275.679780
# 1826    275.746716
# 1829    113.504698
# 1868    110.865788
# 2044    108.916629
# 2343    100.806520
# 2383    107.341982
# 2400    111.246412
# 2648    113.024472
# 2715    111.478582
# 2742    113.175965
# 2775    114.463900
# 2777    111.994028
# 2811    114.733545
# 2877    114.371450
# 3179     94.908977
# 3186    110.903598
# 3217     98.367915
# 3230    114.807578
# 3269     94.812545
# Name: Hardness, dtype: float64

# %%
d.Hardness[d.Hardness>up]=low
# Out:
# <ipython-input-131-2cae41d286ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Hardness[d.Hardness>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 51      100.457615
# 67      103.464759
# 149     104.752425
# 189     112.299485
# 215     105.859264
# 227     112.820254
# 246     103.173587
# 258      98.771644
# 263      47.432000
# 278      81.710895
# 309     113.831112
# 317      77.459586
# 335      94.091307
# 379      73.492234
# 1525    108.699077
# 1536    106.380113
# 1542     97.280909
# 1649     98.452931
# 1743    107.383327
# 1747    115.300182
# 1829    113.504698
# 1868    110.865788
# 2044    108.916629
# 2343    100.806520
# 2383    107.341982
# 2400    111.246412
# 2648    113.024472
# 2715    111.478582
# 2742    113.175965
# 2775    114.463900
# 2777    111.994028
# 2811    114.733545
# 2877    114.371450
# 3179     94.908977
# 3186    110.903598
# 3217     98.367915
# 3230    114.807578
# 3269     94.812545
# Name: Hardness, dtype: float64

# %% [markdown]
# **Outlier:Chloramines**

# %%
l=d.Chloramines
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 285     0.530351
# 408     2.484380
# 437     2.981379
# 454     2.993744
# 509     1.683993
# 651     2.750837
# 666     2.577555
# 772     2.866073
# 806     2.862535
# 1106    2.741712
# 1698    2.456014
# 1868    2.621268
# 2206    2.458609
# 2212    2.785718
# 2300    2.498597
# 2302    0.352000
# 2346    2.855790
# 2350    1.390871
# 2352    2.397985
# 2401    1.920271
# 2449    2.386653
# 2470    2.102691
# 2535    2.726766
# 2566    2.654491
# 2586    3.074316
# 2677    2.562255
# 2714    2.648390
# 2796    3.016033
# Name: Chloramines, dtype: float64

# %%
d.Chloramines[d.Chloramines>up]=low
# Out:
# <ipython-input-135-5c7899d64226>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Chloramines[d.Chloramines>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 285     0.530351
# 408     2.484380
# 437     2.981379
# 454     2.993744
# 509     1.683993
# 651     2.750837
# 666     2.577555
# 772     2.866073
# 806     2.862535
# 1106    2.741712
# 1698    2.456014
# 1868    2.621268
# 2206    2.458609
# 2212    2.785718
# 2300    2.498597
# 2302    0.352000
# 2346    2.855790
# 2350    1.390871
# 2352    2.397985
# 2401    1.920271
# 2449    2.386653
# 2470    2.102691
# 2535    2.726766
# 2566    2.654491
# 2586    3.074316
# 2677    2.562255
# 2714    2.648390
# 2796    3.016033
# Name: Chloramines, dtype: float64

# %% [markdown]
# **Outlier:Sulfate**

# %%
l=d.Sulfate
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 51      247.200826
# 118     241.607532
# 130     240.936722
# 227     234.852699
# 253     187.170714
#            ...
# 2851    231.724225
# 2857    252.067267
# 3023    238.844004
# 3086    392.462199
# 3162    254.040977
# Name: Sulfate, Length: 85, dtype: float64

# %%
d.Sulfate[d.Sulfate>up]=low
# Out:
# <ipython-input-139-7497be8b425b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Sulfate[d.Sulfate>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 51      247.200826
# 118     241.607532
# 130     240.936722
# 227     234.852699
# 253     187.170714
#            ...
# 2834    244.086257
# 2851    231.724225
# 2857    252.067267
# 3023    238.844004
# 3162    254.040977
# Name: Sulfate, Length: 80, dtype: float64

# %% [markdown]
# **Outlier:Conductivity**

# %%
l=d.Conductivity
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 1384    181.483754
# Name: Conductivity, dtype: float64

# %%
d.Conductivity[d.Conductivity>up]=low
# Out:
# <ipython-input-143-99cb504c1183>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Conductivity[d.Conductivity>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 1384    181.483754
# Name: Conductivity, dtype: float64

# %% [markdown]
# **Outlier:Organic_carbon**

# %%
l=d.Organic_carbon
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 785     2.200000
# 876     4.966862
# 1390    4.371899
# 1447    4.861631
# 1536    5.218233
# 1663    4.473092
# 1689    5.051695
# 2082    5.188466
# 2138    4.902888
# 2224    4.466772
# 2414    5.196717
# 2680    5.159380
# Name: Organic_carbon, dtype: float64

# %%
d.Organic_carbon[d.Organic_carbon>up]=low
# Out:
# <ipython-input-147-d61115c30e93>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Organic_carbon[d.Organic_carbon>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 785     2.200000
# 876     4.966862
# 1390    4.371899
# 1447    4.861631
# 1536    5.218233
# 1663    4.473092
# 1689    5.051695
# 2082    5.188466
# 2138    4.902888
# 2224    4.466772
# 2414    5.196717
# 2680    5.159380
# Name: Organic_carbon, dtype: float64

# %% [markdown]
# **Outlier:Trihalomethanes**

# %%
l=d.Trihalomethanes
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 61      17.915723
# 133     23.817020
# 204     25.525267
# 245     18.400012
# 330      8.175876
# 374     20.337753
# 518     23.792950
# 630     25.057375
# 698     19.175175
# 719     21.355275
# 951     18.101222
# 1041    23.136611
# 1075    17.000683
# 1123     8.577013
# 1360    16.291505
# 1630    17.527765
# 1699    22.749735
# 1767    22.219327
# 2006    24.532773
# 2121    15.684877
# 2353    18.015272
# 2402    24.914971
# 2490    25.061904
# 2585    24.734227
# 2742    23.075806
# 2949    14.343161
# 3035     0.738000
# Name: Trihalomethanes, dtype: float64

# %%
d.Trihalomethanes[d.Trihalomethanes>up]=low
# Out:
# <ipython-input-151-35e7f8a37c0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Trihalomethanes[d.Trihalomethanes>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 61      17.915723
# 133     23.817020
# 204     25.525267
# 245     18.400012
# 330      8.175876
# 374     20.337753
# 518     23.792950
# 630     25.057375
# 698     19.175175
# 719     21.355275
# 951     18.101222
# 1041    23.136611
# 1075    17.000683
# 1123     8.577013
# 1360    16.291505
# 1630    17.527765
# 1699    22.749735
# 1767    22.219327
# 2006    24.532773
# 2121    15.684877
# 2353    18.015272
# 2402    24.914971
# 2490    25.061904
# 2585    24.734227
# 2742    23.075806
# 2949    14.343161
# 3035     0.738000
# Name: Trihalomethanes, dtype: float64

# %% [markdown]
# **Outlier: Turbidity**

# %%
l=d.Turbidity
q1=l.quantile(0.25)
q2=l.quantile(0.75)
iqr=q2-q1
low=q1-1.5*iqr
up=q2+1.5*iqr

# %%
l[(l<low) | (l>up)]
# Out:
# 593     1.680554
# 789     1.812529
# 1290    1.496101
# 1682    1.687625
# 1892    1.492207
# 1927    1.659799
# 2724    1.641515
# 2796    1.844372
# 3042    1.450000
# 3166    1.801327
# Name: Turbidity, dtype: float64

# %%
d.Turbidity[d.Turbidity>up]=low
# Out:
# <ipython-input-155-1b5221210777>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.Turbidity[d.Turbidity>up]=low

# %%
l[(l<low) | (l>up)]
# Out:
# 593     1.680554
# 789     1.812529
# 1290    1.496101
# 1682    1.687625
# 1892    1.492207
# 1927    1.659799
# 2724    1.641515
# 2796    1.844372
# 3042    1.450000
# 3166    1.801327
# Name: Turbidity, dtype: float64

# %% [markdown]
# ```
# `[# This is formatted as code](https://)`
# ```
#
# # **Step 6: Data spliting**
# Data splitting is when data is divided into two or more subsets. Typically, with a two-part split, one part is used to evaluate or test the data and the other to train the model. Data splitting is an important aspect of data science, particularly for creating models based on data.

# %%
from sklearn.model_selection import train_test_split
X = d.drop('Potability', axis=1)
y = d['Potability']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# # **Step 7: Model Fitting and Evaluating**
# Model fitting is a measure of how well a machine learning model generalizes to similar data to that on which it was trained. A model that is well-fitted produces more accurate outcomes. A model that is overfitted matches the data too closely. A model that is underfitted doesn't match closely enough.

# %%
#logistic regression model
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score
accuracy_lr = accuracy_score(y_test, y_pred)*100
accuracy_lr
# Out:
# 62.27106227106227

# %%
#DecisionTree Classifier model
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion= 'gini', min_samples_split= 10, splitter= 'best')
dt.fit(X_train,y_train)
prediction=dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score
accuracy_dt=accuracy_score(y_test,prediction)*100
accuracy_dt
# Out:
# 56.65445665445665

# %%
#RandomForest Classifier model
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, roc_curve, roc_auc_score
accuracy_rf = accuracy_score(y_test, y_pred)*100
accuracy_rf
# Out:
# 65.8119658119658

# %% [markdown]
# # **Step 8: Sample testing**
# The one sample t-test is a statistical procedure used to determine whether a sample of observations could have been generated by a process with a specific mean. Suppose you are interested in determining whether an assembly line produces laptop computers that weigh five pounds.

# %%
#logistic regression model
lrm=model.predict([[5.735724, 158.318741,25363.016594,7.728601,377.543291,568.304671,13.626624,75.952337,4.732954]])
lrm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
#DecisionTree Classifier model
dtm=dt.predict([[5.735724, 158.318741,25363.016594,7.728601,377.543291,568.304671,13.626624,75.952337,4.732954]])
dtm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
#RandomForest Classifier model
rfm=rf_model.predict([[5.735724, 158.318741,25363.016594,7.728601,377.543291,568.304671,13.626624,75.952337,4.732954]])
rfm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# # **Step 9: Accuracy score graph for different model**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
xpoints = np.array(['Logistic Regression','Dicision Tree classifier','Random Forest Classifier'])
y=np.array([62.27106227106227,56.65445665445665,65.8119658119658])
plt.barh(xpoints,y)
plt.title("accuracy score for different model")
plt.ylabel("Models")
plt.xlabel("Accuracy in percentage")
plt.show()

# %% [markdown]
# # **Step 10: Predictive model**

# %%
def model():
  ph=float(input("Enter ph value : "))
  hardness=float(input("Enter Hardness value : "))
  solids=float(input("Enter Solids value : "))
  chloramines=float(input("Enter Chloramines value : "))
  sulfate=float(input("Enter Sulfate value : "))
  conductivity=float(input("Enter Conductivity value : "))
  organic_carbon=float(input("Enter Organic_carbon value : "))
  trihalomethanes=float(input("Enter Trihalomethanes value : "))
  turbidity=float(input("Enter Turbidity value : "))
  x=np.array([ph,hardness,solids,chloramines,sulfate,conductivity,organic_carbon,trihalomethanes,turbidity])
  x=x.reshape(1,-1)
  y=dt.predict(x)
  if y[0]==1:
    print("\033[1m "+"This Water Is Not Drinkable"+"\033[0;0m")
  else:
    print("\033[1m "+"This Water Is  Drinkable"+"\033[0;0m")

# %%
model()
# Out:
# Enter ph value : 12
# Enter Hardness value : 12
# Enter Solids value : 12
# Enter Chloramines value : 12
# Enter Sulfate value : 12
# Enter Conductivity value : 12
# Enter Organic_carbon value : 12
# Enter Trihalomethanes value : 12
# Enter Turbidity value : 12
#  This Water Is  Drinkable
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
